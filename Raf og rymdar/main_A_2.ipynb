# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

from matplotlib.ticker import NullFormatter
plt.ion()



# fastar til að reikna n
q = 1.602*10**(-19)
k_B = 1.38*10**(-23)
T = 298

#1N4148
rev_1N = pd.read_csv('1nrvs.txt',sep='\t')
x_1N = rev_1N['Voltage (V)']
y_1N = rev_1N['Current (A)']
#y_1N = -np.log(np.abs(y_1N))
x_1N = x_1N[1:]
y_1N = y_1N[1:]
#print(y_1N)
#BZX-55C13
rev_BZX = pd.read_csv('bzrvs.txt',sep='\t')
x_BZX = rev_BZX['Voltage (V)']
y_BZX = rev_BZX['Current (A)']

print(y_BZX)


#BYS26-45
rev_BYS = pd.read_csv('bysrvs.txt',sep='\t')
x_BYS = rev_BYS['Voltage (V)']
y_BYS = rev_BYS['Current (A)']

x_BYS = x_BYS[1:]
y_BYS = y_BYS[1:]
#print(y_BYS)

#Blár tvistur
rev_blue = pd.read_csv('blarvs.txt',sep='\t')
x_BLUE = rev_blue['Voltage (V)']
y_BLUE = rev_blue['Current (A)']

#print(y_BLUE)
print(np.max(y_1N))
# 1N4148
plt.subplot(221)
plt.scatter(x_1N, y_1N,s=20)
#plt.yscale('symlog')
plt.title('p-n tvistur')
plt.grid(True, which="both")
#plt.xlim(0.9*min(x_1N),1.1*max(x_1N))
plt.ylim(1.05*np.min(y_1N),1.1*np.max(y_1N) )
plt.xlabel('Spenna (V)')
plt.ylabel('Straumur (A)')
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
#plt.locator_params(axis='y', numticks=1000)



# BZX-55C13
plt.subplot(222)
#plt.plot(x_BZX,y_BZX)
plt.scatter(x_BZX,y_BZX,s=20)
#plt.yscale('symlog')
plt.title('Zener tvistur')
plt.grid(True)
#plt.xlim([-15,0])
plt.ylim(-0.012,0.000001)
plt.xlabel('Spenna (V)')
plt.ylabel('Straumur (A)')
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.locator_params(axis='y', numticks=10)

# BYS26-45
plt.subplot(223)
plt.scatter(x_BYS,y_BYS,s=20)
#plt.yscale('symlog')
plt.title('Schottky tvistur')
plt.grid(True)
#plt.xlim([-64,0])
plt.ylim(-3.0E-7,-8.0E-5)
plt.xlabel('Spenna (V)')
plt.ylabel('Straumur (A)')
#plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.locator_params(axis='y', numticks=8)

# Blár tvistur
plt.subplot(224)
plt.grid(True)
plt.scatter(x_BLUE, y_BLUE,s=20)
#plt.yscale('symlog')
plt.title('Blár ljóstvistur')

#plt.xlim([-43,0])
plt.ylim(-9.0E-14,-4.0E-6)
#plt.yticks(list(plt.yticks()[0]) + [-10.0E-12])
plt.xlabel('Spenna (V)')
plt.ylabel('Straumur (A)')
#plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.locator_params(axis='y', numticks=6)
# Format the minor tick labels of the y-axis into empty strings with
# `NullFormatter`, to avoid cumbering the axis with too many labels.
#plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=2, bottom=0, left=0, right=2, hspace=0.25,
                    wspace=0.35)


#plt.show()
plt.savefig('MAIN_A_rev.png', dpi=300, bbox_inches='tight')
# Out:
# 0     9.733739e-11
# 1     3.719200e-11
# 2     2.371844e-11
# 3     1.649614e-11
# 4    -1.138017e-11
# 5     7.795126e-12
# 6     1.941042e-11
# 7     1.531369e-11
# 8    -1.053507e-11
# 9    -3.173825e-11
# 10    1.987482e-11
# 11    1.860803e-11
# 12    4.652620e-11
# 13   -3.072440e-11
# 14   -3.575043e-11
# 15   -5.450357e-11
# 16    3.803666e-11
# 17    3.799436e-11
# 18    4.665285e-11
# 19   -5.061779e-11
# 20   -5.171610e-11
# 21   -4.778794e-11
# 22    5.624068e-11
# 23    3.727649e-11
# 24    4.040193e-11
# 25   -6.012105e-11
# 26   -6.915959e-11
# 27   -5.560158e-11
# 28    4.547029e-11
# 29    3.972594e-11
#           ...
# 41   -3.587738e-11
# 42   -5.180054e-11
# 43    4.038714e-13
# 44    8.133355e-12
# 45    1.054071e-11
# 46   -6.578069e-11
# 47   -7.752252e-11
# 48   -7.667786e-11
# 49    1.936806e-11
# 50    1.286377e-11
# 51   -1.412553e-11
# 52   -8.225304e-11
# 53   -8.102813e-11
# 54   -5.158926e-11
# 55   -2.814801e-11
# 56   -4.580297e-11
# 57   -1.157889e-10
# 58   -1.286709e-10
# 59   -1.114807e-10
# 60   -1.211108e-10
# 61   -2.164388e-10
# 62   -3.637180e-10
# 63   -4.451721e-09
# 64   -9.999721e-03
# 65   -9.999734e-03
# 66   -9.999740e-03
# 67   -9.999740e-03
# 68   -9.999733e-03
# 69   -9.999739e-03
# 70   -9.999736e-03
# Name: Current (A), Length: 71, dtype: float64
# -2.117716e-09
